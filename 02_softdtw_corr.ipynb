# %% [markdown]
# # Lab 2: Soft-DTW
#
# * Author: Romain Tavenard (@rtavenar)
# * License: CC-BY-NC-SA
#
# A lab session from a course on Machine Learning for Time Series at ENSAI.
# One can find lecture notes for this course [there](https://rtavenar.github.io/ml4ts_ensai/).

# %%
import numpy as np
import matplotlib.pyplot as plt

from tslearn.metrics import soft_dtw, soft_dtw_alignment

# %% [markdown]
# ## Impact of the $\gamma$ parameter
#
# Let us define time series `x0` and `x1` as follows:

# %%
size = 50
x0 = np.zeros((size, ))
x0[20:20+size//2] = np.sin(np.linspace(0, 2 * np.pi, size // 2))

x1 = np.zeros((size, ))
x1[5:5+size//2] = np.sin(np.linspace(0, 2 * np.pi, size // 2))

plt.figure()
plt.plot(x0, 'r-', label='x0')  # red
plt.plot(x1, 'b-', label='x1')  # blue
plt.legend()
plt.show()

# %% [markdown]
# **Question #1.** Using the [`soft_dtw_alignment`](https://tslearn.readthedocs.io/en/latest/gen_modules/metrics/tslearn.metrics.soft_dtw_alignment.html)
# function from `tslearn`, study the impact of parameter `\gamma` on soft-alignment matrices $A_\gamma$.
#
# _NB:_ `plt.imshow(m)` allows one to view matrix `m` represented as an image.

# %%
A_gamma, sdist = soft_dtw_alignment(x0, x1, gamma=100.)
plt.imshow(A_gamma)

# %% [markdown]
# ## Gradient Descent on a SoftDTW objective
#
# The following function computes gradients of $\text{soft-}DTW^\gamma(x, y)$ with respect to $x$
# for univariate time series:

# %%
import tslearn

def soft_dtw_grad(x, y, gamma):    
    D = tslearn.metrics.SquaredEuclidean(x.reshape((-1, 1)), y.reshape((-1, 1)))
    sdtw = tslearn.metrics.SoftDTW(D, gamma=gamma)
    sdtw.compute()
    A_gamma = sdtw.grad()
    grad = D.jacobian_product(A_gamma)
    return grad

# %% [markdown]
# Also, for the next few questions, you might want to use the following function that generates an
# animation to help visualize gradient descent.

# %%
from celluloid import Camera
from IPython.display import HTML

def animate_gradient_descent(list_of_successive_time_series, show_x1=False):
    fig = plt.figure()
    camera = Camera(fig)
    for x in list_of_successive_time_series:
        plt.plot(x.ravel(), 'k-')
        plt.plot(x0, 'r-', label='x0')
        if show_x1:
            plt.plot(x1, 'b-', label='x1')
        camera.snap()    
    anim = camera.animate()
    plt.close()
    return HTML(anim.to_jshtml())

# %% [markdown]
# **Question #2.** Implement a gradient-descent scheme to minimize (with respect to $x$) the quantity
# $\text{soft-}DTW^\gamma(x, x_0)$ where $x_0$ is the array `x0` defined above.

# %%
eta = 1e-1
epochs = 100
gamma = 1.

list_x = [.1 * np.random.randn(size, 1)]

for e in range(epochs):
    grad = soft_dtw_grad(list_x[-1], x0, gamma)
    list_x.append(
        list_x[e] - eta * grad
    )

animate_gradient_descent(list_x)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img49bdfc33b93948398d2773c0b2a72896">
#   <div class="anim-controls">
#     <input id="_anim_slider49bdfc33b93948398d2773c0b2a72896" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim49bdfc33b93948398d2773c0b2a72896.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim49bdfc33b93948398d2773c0b2a72896.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim49bdfc33b93948398d2773c0b2a72896.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim49bdfc33b93948398d2773c0b2a72896.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim49bdfc33b93948398d2773c0b2a72896.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim49bdfc33b93948398d2773c0b2a72896.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim49bdfc33b93948398d2773c0b2a72896.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim49bdfc33b93948398d2773c0b2a72896.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim49bdfc33b93948398d2773c0b2a72896.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim49bdfc33b93948398d2773c0b2a72896.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select49bdfc33b93948398d2773c0b2a72896"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_49bdfc33b93948398d2773c0b2a72896"
#              >
#       <label for="_anim_radio1_49bdfc33b93948398d2773c0b2a72896">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_49bdfc33b93948398d2773c0b2a72896"
#              checked>
#       <label for="_anim_radio2_49bdfc33b93948398d2773c0b2a72896">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_49bdfc33b93948398d2773c0b2a72896"
#              >
#       <label for="_anim_radio3_49bdfc33b93948398d2773c0b2a72896">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img49bdfc33b93948398d2773c0b2a72896";
#     var slider_id = "_anim_slider49bdfc33b93948398d2773c0b2a72896";
#     var loop_select_id = "_anim_loop_select49bdfc33b93948398d2773c0b2a72896";
#     var frames = new Array(101);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjUuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/YYfK9AAAACXBIWXMAAAsT\
# AAALEwEAmpwY

# %% [markdown]
# **Question #3.** Use the code above to estimate a soft-DTW barycenter of `x0` and `x1` via
# gradient-descent optimization.

# %% [markdown]
# $$
#     \mathcal{L} = \frac{1}{2} \left[ \text{softDTW}(z, x_0) + \text{softDTW}(z, x_1) \right]
# $$
#
# then
#
# $$
#     \nabla_z \mathcal{L} = \frac{1}{2} \left[ \nabla_z \text{softDTW}(z, x_0) + \nabla_z \text{softDTW}(z, x_1) \right]
# $$

# %%
eta = 1e-1
epochs = 100
gamma = .1

list_x = [np.random.randn(size, 1)]

for e in range(epochs):
    grad0 = soft_dtw_grad(list_x[-1], x0, gamma)
    grad1 = soft_dtw_grad(list_x[-1], x1, gamma)
    list_x.append(
        list_x[e] - eta * (grad0 + grad1)
    )

animate_gradient_descent(list_x, show_x1=True)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgfb8b268e30d848b99b802adfab36c0a3">
#   <div class="anim-controls">
#     <input id="_anim_sliderfb8b268e30d848b99b802adfab36c0a3" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animfb8b268e30d848b99b802adfab36c0a3.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animfb8b268e30d848b99b802adfab36c0a3.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animfb8b268e30d848b99b802adfab36c0a3.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animfb8b268e30d848b99b802adfab36c0a3.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animfb8b268e30d848b99b802adfab36c0a3.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animfb8b268e30d848b99b802adfab36c0a3.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animfb8b268e30d848b99b802adfab36c0a3.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animfb8b268e30d848b99b802adfab36c0a3.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animfb8b268e30d848b99b802adfab36c0a3.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animfb8b268e30d848b99b802adfab36c0a3.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectfb8b268e30d848b99b802adfab36c0a3"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_fb8b268e30d848b99b802adfab36c0a3"
#              >
#       <label for="_anim_radio1_fb8b268e30d848b99b802adfab36c0a3">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_fb8b268e30d848b99b802adfab36c0a3"
#              checked>
#       <label for="_anim_radio2_fb8b268e30d848b99b802adfab36c0a3">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_fb8b268e30d848b99b802adfab36c0a3"
#              >
#       <label for="_anim_radio3_fb8b268e30d848b99b802adfab36c0a3">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgfb8b268e30d848b99b802adfab36c0a3";
#     var slider_id = "_anim_sliderfb8b268e30d848b99b802adfab36c0a3";
#     var loop_select_id = "_anim_loop_selectfb8b268e30d848b99b802adfab36c0a3";
#     var frames = new Array(101);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjUuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/YYfK9AAAACXBIWXMAAAsT\
# AAALEwEAmpwY
